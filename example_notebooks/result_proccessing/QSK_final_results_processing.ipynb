# %% [markdown]
# # QSK: Result Processing
#
# This notebook is part of the work: arXiv:2609.26032 [quant-ph]
# "Hyperbolic Restricted Boltzmann Machine Neural Quantum State" by HL Dao

# %%
import sys
sys.path.append('../../qsk_hrbm_utility')
from plotting_utility import *

# %% [markdown]
# # Exact metrics

# %%
export_exact_gs_metrics()
# Out:
# Exact GS metrics successfully saved to: exact_gs_metrics.csv
#      N  seed_qsk  exact_energy  exact_S_2  exact_S_vN
# 0   14      1234    -14.764654   0.238397    0.523197
# 1   14      4444    -14.762866   0.241584    0.527381
# 2   14      5678    -14.784242   0.249586    0.541275
# 3   14      6666    -14.884761   0.300660    0.612231
# 4   14      9012    -14.777944   0.223110    0.469309
# 5   14      9999    -15.419419   0.402053    0.746667
# 6   16      1234    -16.992467   0.245180    0.553498
# 7   16      4444    -16.946620   0.225920    0.529474
# 8   16      5678    -17.101175   0.406380    0.703491
# 9   16      6666    -17.079820   0.257172    0.544865
# 10  16      9012    -16.823153   0.227077    0.513519
# 11  16      9999    -17.128633   0.396925    0.770161
# 12  18      1234    -18.989854   0.254455    0.593687
# 13  18      4444    -19.142463   0.361591    0.718623
# 14  18      5678    -18.995777   0.283652    0.655164
# ...

# %% [markdown]
# # Scaling benchmark per seed

# %%
plot_scaling_benchmark_per_seed()
# Out:
# Saved seed 1234 CSV metrics to: scaling_benchmark_seed_1234_metrics.csv
# Saved seed scaling plot to: scaling_benchmark_seed_1234.png
# Saved seed 4444 CSV metrics to: scaling_benchmark_seed_4444_metrics.csv
# Saved seed scaling plot to: scaling_benchmark_seed_4444.png
# Saved seed 5678 CSV metrics to: scaling_benchmark_seed_5678_metrics.csv
# Saved seed scaling plot to: scaling_benchmark_seed_5678.png
# Saved seed 6666 CSV metrics to: scaling_benchmark_seed_6666_metrics.csv
# Saved seed scaling plot to: scaling_benchmark_seed_6666.png
# Saved seed 9012 CSV metrics to: scaling_benchmark_seed_9012_metrics.csv
# Saved seed scaling plot to: scaling_benchmark_seed_9012.png
# Saved seed 9999 CSV metrics to: scaling_benchmark_seed_9999_metrics.csv
# Saved seed scaling plot to: scaling_benchmark_seed_9999.png

# %% [markdown]
# # Scaling benchmark all seeds

# %%
plot_scaling_benchmark_all_seeds(data_dir="")
# Out:
# Aggregated all-seeds CSV metrics saved to: scaling_benchmark_all_seeds_metrics.csv
# Scaling figure successfully saved to: scaling_benchmark.png
