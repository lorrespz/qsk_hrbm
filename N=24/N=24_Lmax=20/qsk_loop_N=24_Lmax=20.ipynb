# %% [markdown]
# # QSK (N=24)
#
# - V1: HRBM, Lmax=10
# - V2: HRBM, Lmax=20

# %%
from kaggle_secrets import UserSecretsClient
import os
# 1. Securely grab the token from the Kaggle vault
user_secrets = UserSecretsClient()
gh_token = user_secrets.get_secret("RBM_private_github")

# 2. Define the GitHub details
USERNAME = "lorrespz"
REPO = "qsk_hrbm"

# 3. Inject the token dynamically into the clone URL
# This clones it quietly without saving the token to any text files or logs
os.system(f"git clone https://{USERNAME}:{gh_token}@github.com/{USERNAME}/{REPO}.git")

print(f"Successfully cloned private repository: {REPO}")
# Out:
# Cloning into 'qsk_hrbm'...
# Successfully cloned private repository: qsk_hrbm

# %%
import numpy as np, scipy as sp

# Write Kaggle's exact active C-library versions to a constraints file
with open("/tmp/constraints.txt", "w") as f:
    f.write(f"numpy=={np.__version__}\nscipy=={sp.__version__}\n")

# Install NetKet + OpenFermion and all dependencies without touching NumPy or SciPy
# %pip install netket openfermion -c /tmp/constraints.txt -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.2/969.2 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 MB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 68.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.8/185.8 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 3.7 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.

# %%
import jax
print("JAX default backend:", jax.default_backend())
print("Available devices:", jax.devices())
# Out:
# JAX default backend: gpu
# Available devices: [CudaDevice(id=0)]

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import kagglehub

import sys
import time
sys.path.append('/kaggle/working/qsk_hrbm/qsk_hrbm_utility')
from qsk_netket_pipeline import *
# Use sk_cpu instead of sk to avoid crashing due to out-of-memory error
from sk_cpu import *
from hrbm import *
# Out:
# ∣NK⟩ Tip: 😍 Love? 😡 Hate? these tips? Let us know at https://forms.gle/ej8eDGFRu2mww5mQ9

# %%
seed_qsk_list=[1234, 5678, 9012]
seed_nqs_list = [101, 202, 303]

# %%
# number of spins
N = 24
# Common hyperparams
alpha=1
lr=0.05
n_samples = 2016
epochs=450

# %%
def nqs_training(N, hamiltonian, exact_E, model, lr, alpha, n_samples, seed_nqs, model_name):
    sampler = nk.sampler.MetropolisLocal(hamiltonian)    
    optimizer = optax.inject_hyperparams(optax.sgd)(learning_rate=lr)
    key_model, key_sampler, key_vstate = set_seed(seed_nqs)
    vstate = nk.vqs.MCState(sampler, model, n_samples=n_samples, seed=key_vstate)
    print("Has", vstate.n_parameters, "parameters")
    
    start = time.time()
    netket_pipeline(N, model, sampler, H, vstate, optimizer, 
                iter_num=epochs,  exact_E =exact_E,  holomorphic=False,
                log_filename=f"qsk_N={N}/seed_qsk={seed_qsk}/seed={seed_nqs}/{model_name}_alpha={alpha}_ML")
    
    end = time.time()
    print(f'Time taken = {end-start} (secs)')

# %% [markdown]
# # RBM

# %%
for seed_qsk in seed_qsk_list:
    print('********************************************************************************')
    print(f'Current seed_qsk={seed_qsk}')
    hamiltonian, H = generate_hamiltonian_sk(N=N, seed=seed_qsk)
    _, ground_state_vec = generate_state_sk(N=N, seed=seed_qsk)
    #sp_h = H.to_sparse()
    sp_h = generate_hamiltonian_sk_scipy(N, seed_qsk)
    exact_E = (ground_state_vec.conj().T @ sp_h @ ground_state_vec).real
    print(f"Exact ED Ground State Energy for seed {seed_qsk} is {exact_E:.6f}")
    print('********************************************************************************')
    
    for seed_nqs in seed_nqs_list:
        print(f'Current seed_nqs={seed_nqs}')
        model = nk.models.RBM(alpha=alpha) 
        nqs_training(N, hamiltonian, exact_E, model, lr, alpha, n_samples,  seed_nqs, 'rbm')
        print('===================================================================================')
# Out:
# ********************************************************************************
# Current seed_qsk=1234
# Generating N=24 exact ground state on CPU RAM...
# Sparse matrix constructed (16777216x16777216). Diagonalizing via SciPy ARPACK...
# Exact GS saved to sk_ground_state_N=24_seed=1234.npy. Energy = -25.424855
# Exact ED Ground State Energy for seed 1234 is -25.424855
# ********************************************************************************
# Current seed_nqs=101
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.978369, Var = 5.2528, LR = 5.00e-02
# Iteration 010: Energy = -25.363569, Var = 0.3182, LR = 5.00e-02
# Iteration 020: Energy = -25.402699, Var = 0.1705, LR = 5.00e-02
# Iteration 030: Energy = -25.402999, Var = 0.1326, LR = 5.00e-02
# Iteration 040: Energy = -25.418751, Var = 0.1147, LR = 5.00e-02
# Iteration 050: Energy = -25.411742, Var = 0.1020, LR = 5.00e-02
# Iteration 060: Energy = -25.415503, Var = 0.0883, LR = 5.00e-02
# Iteration 070: Energy = -25.418962, Var = 0.0816, LR = 5.00e-02
# Iteration 080: Energy = -25.420778, Var = 0.0703, LR = 5.00e-02
# Iteration 090: Energy = -25.409135, Var = 0.0657, LR = 5.00e-02
# Iteration 100: Energy = -25.410326, Var = 0.0575, LR = 5.00e-02
# Iteration 110: Energy = -25.421077, Var = 0.0525, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 119: Energy stalled at -25.416713
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 120: Energy = -25.415237, Var = 0.0465, LR = 2.50e-02
# Iteration 130: Energy = -25.415348, Var = 0.0443, LR = 2.50e-02
# Iteration 140: Energy = -25.420101, Var = 0.0432, LR = 2.50e-02
# Iteration 150: Energy = -25.415301, Var = 0.0405, LR = 2.50e-02
# Iteration 160: Energy = -25.415705, Var = 0.0366, LR = 2.50e-02
# Iteration 170: Energy = -25.419504, Var = 0.0349, LR = 2.50e-02
# Iteration 180: Energy = -25.423636, Var = 0.0359, LR = 2.50e-02
# Iteration 190: Energy = -25.419104, Var = 0.0328, LR = 2.50e-02
# Iteration 200: Energy = -25.421008, Var = 0.0343, LR = 2.50e-02
# Iteration 210: Energy = -25.417473, Var = 0.0309, LR = 2.50e-02
# Iteration 220: Energy = -25.419325, Var = 0.0315, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 223: Energy stalled at -25.418245
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 230: Energy = -25.420875, Var = 0.0302, LR = 1.25e-02
# Iteration 240: Energy = -25.422271, Var = 0.0304, LR = 1.25e-02
# Iteration 250: Energy = -25.418599, Var = 0.0257, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 253: Energy stalled at -25.415581
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 260: Energy = -25.423566, Var = 0.0285, LR = 6.25e-03
# Iteration 270: Energy = -25.424588, Var = 0.0269, LR = 6.25e-03
# Iteration 280: Energy = -25.431720, Var = 0.0287, LR = 6.25e-03
# Iteration 290: Energy = -25.425709, Var = 0.0268, LR = 6.25e-03
# Iteration 300: Energy = -25.416899, Var = 0.0264, LR = 6.25e-03
# Iteration 310: Energy = -25.422125, Var = 0.0263, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 310: Energy stalled at -25.422125
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 320: Energy = -25.419409, Var = 0.0285, LR = 3.13e-03
# Iteration 330: Energy = -25.411970, Var = 0.0275, LR = 3.13e-03
# Iteration 340: Energy = -25.423962, Var = 0.0273, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 340: Energy stalled at -25.423962
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 350: Energy = -25.412722, Var = 0.0268, LR = 1.56e-03
# Iteration 360: Energy = -25.424012, Var = 0.0250, LR = 1.56e-03
# Iteration 370: Energy = -25.426559, Var = 0.0268, LR = 1.56e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 370: Energy stalled at -25.426559
#  >>> Lowering LR: 1.56e-03 --> 7.81e-04
# =======================================================
#
# Iteration 380: Energy = -25.419794, Var = 0.0281, LR = 7.81e-04
#
# ============================================================
#  >>> [EARLY STOPPING] Step 380: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 280 (Energy: -25.431720)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79fbb62e1080> requested to stop the run.
#
# Restored best model weights from step 280 (Energy: -25.431720)
#
# Relative error   : 0.00027002856345576063
#
# ========================================
# Mean Energy:        -25.425612
# Error Bar:          ± 0.003668
# Variance:           0.026135
# Final VMC Energy:   -25.417889
# Energy per Fermion: -1.059401
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=1234/seed=101/rbm_alpha=1_ML_final_params.mpack
# Time taken = 57.61928606033325 (secs)
# ===================================================================================
# Current seed_nqs=202
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.986302, Var = 4.9060, LR = 5.00e-02
# Iteration 010: Energy = -25.343708, Var = 0.3402, LR = 5.00e-02
# Iteration 020: Energy = -25.381494, Var = 0.1736, LR = 5.00e-02
# Iteration 030: Energy = -25.404289, Var = 0.1452, LR = 5.00e-02
# Iteration 040: Energy = -25.407744, Var = 0.1215, LR = 5.00e-02
# Iteration 050: Energy = -25.406150, Var = 0.1122, LR = 5.00e-02
# Iteration 060: Energy = -25.409986, Var = 0.1030, LR = 5.00e-02
# Iteration 070: Energy = -25.412214, Var = 0.0822, LR = 5.00e-02
# Iteration 080: Energy = -25.411048, Var = 0.0836, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 084: Energy stalled at -25.417371
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 090: Energy = -25.420155, Var = 0.0873, LR = 2.50e-02
# Iteration 100: Energy = -25.415338, Var = 0.0762, LR = 2.50e-02
# Iteration 110: Energy = -25.415071, Var = 0.0697, LR = 2.50e-02
# Iteration 120: Energy = -25.414587, Var = 0.0682, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 127: Energy stalled at -25.415054
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 130: Energy = -25.426869, Var = 0.0716, LR = 1.25e-02
# Iteration 140: Energy = -25.410450, Var = 0.0655, LR = 1.25e-02
# Iteration 150: Energy = -25.420480, Var = 0.0613, LR = 1.25e-02
# Iteration 160: Energy = -25.419313, Var = 0.0596, LR = 1.25e-02
# Iteration 170: Energy = -25.420910, Var = 0.0605, LR = 1.25e-02
# Iteration 180: Energy = -25.420272, Var = 0.0596, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 184: Energy stalled at -25.417412
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 190: Energy = -25.412820, Var = 0.0558, LR = 6.25e-03
# Iteration 200: Energy = -25.418810, Var = 0.0582, LR = 6.25e-03
# Iteration 210: Energy = -25.416219, Var = 0.0544, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 214: Energy stalled at -25.416515
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 220: Energy = -25.424434, Var = 0.0539, LR = 3.13e-03
# Iteration 230: Energy = -25.417041, Var = 0.0552, LR = 3.13e-03
# Iteration 240: Energy = -25.421599, Var = 0.0532, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 245: Energy stalled at -25.414094
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 250: Energy = -25.416754, Var = 0.0565, LR = 1.56e-03
# Iteration 260: Energy = -25.423820, Var = 0.0563, LR = 1.56e-03
# Iteration 270: Energy = -25.414786, Var = 0.0569, LR = 1.56e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 275: Energy stalled at -25.417923
#  >>> Lowering LR: 1.56e-03 --> 7.81e-04
# =======================================================
#
# Iteration 280: Energy = -25.413057, Var = 0.0518, LR = 7.81e-04
# Iteration 290: Energy = -25.413468, Var = 0.0549, LR = 7.81e-04
# Iteration 300: Energy = -25.416073, Var = 0.0514, LR = 7.81e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 305: Energy stalled at -25.421482
#  >>> Lowering LR: 7.81e-04 --> 3.91e-04
# =======================================================
#
# Iteration 310: Energy = -25.421399, Var = 0.0575, LR = 3.91e-04
#
# ============================================================
#  >>> [EARLY STOPPING] Step 315: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 215 (Energy: -25.432582)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88de53ec0> requested to stop the run.
#
# Restored best model weights from step 215 (Energy: -25.432582)
#
# Relative error   : 0.00030392648062149284
#
# ========================================
# Mean Energy:        -25.413445
# Error Bar:          ± 0.005440
# Variance:           0.059328
# Final VMC Energy:   -25.422600
# Energy per Fermion: -1.058894
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=1234/seed=202/rbm_alpha=1_ML_final_params.mpack
# Time taken = 34.81703567504883 (secs)
# ===================================================================================
# Current seed_nqs=303
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -24.024727, Var = 5.1978, LR = 5.00e-02
# Iteration 010: Energy = -25.370474, Var = 0.3462, LR = 5.00e-02
# Iteration 020: Energy = -25.397355, Var = 0.1671, LR = 5.00e-02
# Iteration 030: Energy = -25.394966, Var = 0.1391, LR = 5.00e-02
# Iteration 040: Energy = -25.415333, Var = 0.1175, LR = 5.00e-02
# Iteration 050: Energy = -25.401235, Var = 0.1025, LR = 5.00e-02
# Iteration 060: Energy = -25.414476, Var = 0.0919, LR = 5.00e-02
# Iteration 070: Energy = -25.417041, Var = 0.0851, LR = 5.00e-02
# Iteration 080: Energy = -25.415446, Var = 0.0719, LR = 5.00e-02
# Iteration 090: Energy = -25.420261, Var = 0.0713, LR = 5.00e-02
# Iteration 100: Energy = -25.412609, Var = 0.0634, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 109: Energy stalled at -25.417261
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 110: Energy = -25.407831, Var = 0.0596, LR = 2.50e-02
# Iteration 120: Energy = -25.402472, Var = 0.0527, LR = 2.50e-02
# Iteration 130: Energy = -25.422494, Var = 0.0492, LR = 2.50e-02
# Iteration 140: Energy = -25.414261, Var = 0.0471, LR = 2.50e-02
# Iteration 150: Energy = -25.419555, Var = 0.0456, LR = 2.50e-02
# Iteration 160: Energy = -25.421665, Var = 0.0420, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 162: Energy stalled at -25.419745
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 170: Energy = -25.422333, Var = 0.0375, LR = 1.25e-02
# Iteration 180: Energy = -25.431014, Var = 0.0408, LR = 1.25e-02
# Iteration 190: Energy = -25.421764, Var = 0.0377, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 198: Energy stalled at -25.419297
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 200: Energy = -25.426426, Var = 0.0393, LR = 6.25e-03
# Iteration 210: Energy = -25.417032, Var = 0.0387, LR = 6.25e-03
# Iteration 220: Energy = -25.426530, Var = 0.0374, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 228: Energy stalled at -25.415354
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 230: Energy = -25.413276, Var = 0.0396, LR = 3.13e-03
# Iteration 240: Energy = -25.417347, Var = 0.0381, LR = 3.13e-03
# Iteration 250: Energy = -25.418176, Var = 0.0406, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 258: Energy stalled at -25.423439
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 260: Energy = -25.420350, Var = 0.0363, LR = 1.56e-03
#
# ============================================================
#  >>> [EARLY STOPPING] Step 268: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 168 (Energy: -25.431795)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88de8d760> requested to stop the run.
#
# Restored best model weights from step 168 (Energy: -25.431795)
#
# Relative error   : 0.00027296557075553307
#
# ========================================
# Mean Energy:        -25.424197
# Error Bar:          ± 0.004510
# Variance:           0.041176
# Final VMC Energy:   -25.414951
# Energy per Fermion: -1.059342
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=1234/seed=303/rbm_alpha=1_ML_final_params.mpack
# Time taken = 29.650489568710327 (secs)
# ===================================================================================
# ********************************************************************************
# Current seed_qsk=5678
# Generating N=24 exact ground state on CPU RAM...
# Sparse matrix constructed (16777216x16777216). Diagonalizing via SciPy ARPACK...
# Exact GS saved to sk_ground_state_N=24_seed=5678.npy. Energy = -25.342593
# Exact ED Ground State Energy for seed 5678 is -25.342593
# ********************************************************************************
# Current seed_nqs=101
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.969852, Var = 5.0778, LR = 5.00e-02
# Iteration 010: Energy = -25.293275, Var = 0.3464, LR = 5.00e-02
# Iteration 020: Energy = -25.312124, Var = 0.1914, LR = 5.00e-02
# Iteration 030: Energy = -25.327722, Var = 0.1265, LR = 5.00e-02
# Iteration 040: Energy = -25.322713, Var = 0.0971, LR = 5.00e-02
# Iteration 050: Energy = -25.331908, Var = 0.0815, LR = 5.00e-02
# Iteration 060: Energy = -25.324139, Var = 0.0725, LR = 5.00e-02
# Iteration 070: Energy = -25.328636, Var = 0.0625, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 075: Energy stalled at -25.332030
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 080: Energy = -25.339151, Var = 0.0593, LR = 2.50e-02
# Iteration 090: Energy = -25.344328, Var = 0.0547, LR = 2.50e-02
# Iteration 100: Energy = -25.335387, Var = 0.0513, LR = 2.50e-02
# Iteration 110: Energy = -25.336797, Var = 0.0492, LR = 2.50e-02
# Iteration 120: Energy = -25.340212, Var = 0.0432, LR = 2.50e-02
# Iteration 130: Energy = -25.336379, Var = 0.0457, LR = 2.50e-02
# Iteration 140: Energy = -25.336788, Var = 0.0369, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 145: Energy stalled at -25.337054
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 150: Energy = -25.332948, Var = 0.0377, LR = 1.25e-02
# Iteration 160: Energy = -25.340541, Var = 0.0365, LR = 1.25e-02
# Iteration 170: Energy = -25.339486, Var = 0.0369, LR = 1.25e-02
# Iteration 180: Energy = -25.335273, Var = 0.0340, LR = 1.25e-02
# Iteration 190: Energy = -25.334683, Var = 0.0341, LR = 1.25e-02
# Iteration 200: Energy = -25.333003, Var = 0.0326, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 201: Energy stalled at -25.343428
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 210: Energy = -25.343654, Var = 0.0329, LR = 6.25e-03
# Iteration 220: Energy = -25.337535, Var = 0.0321, LR = 6.25e-03
# Iteration 230: Energy = -25.337665, Var = 0.0302, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 235: Energy stalled at -25.334875
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 240: Energy = -25.340882, Var = 0.0288, LR = 3.13e-03
# Iteration 250: Energy = -25.341141, Var = 0.0298, LR = 3.13e-03
# Iteration 260: Energy = -25.339043, Var = 0.0317, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 268: Energy stalled at -25.340118
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 270: Energy = -25.331515, Var = 0.0307, LR = 1.56e-03
# Iteration 280: Energy = -25.334988, Var = 0.0303, LR = 1.56e-03
# Iteration 290: Energy = -25.334726, Var = 0.0285, LR = 1.56e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 298: Energy stalled at -25.335839
#  >>> Lowering LR: 1.56e-03 --> 7.81e-04
# =======================================================
#
# Iteration 300: Energy = -25.341188, Var = 0.0285, LR = 7.81e-04
# Iteration 310: Energy = -25.333304, Var = 0.0304, LR = 7.81e-04
# Iteration 320: Energy = -25.343765, Var = 0.0287, LR = 7.81e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 328: Energy stalled at -25.337149
#  >>> Lowering LR: 7.81e-04 --> 3.91e-04
# =======================================================
#
# Iteration 330: Energy = -25.340664, Var = 0.0317, LR = 3.91e-04
#
# ============================================================
#  >>> [EARLY STOPPING] Step 338: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 238 (Energy: -25.347837)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88ded4e00> requested to stop the run.
#
# Restored best model weights from step 238 (Energy: -25.347837)
#
# Relative error   : 0.000206930628920338
#
# ========================================
# Mean Energy:        -25.333886
# Error Bar:          ± 0.003733
# Variance:           0.028302
# Final VMC Energy:   -25.337833
# Energy per Fermion: -1.055579
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=5678/seed=101/rbm_alpha=1_ML_final_params.mpack
# Time taken = 37.3301637172699 (secs)
# ===================================================================================
# Current seed_nqs=202
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.975350, Var = 4.9320, LR = 5.00e-02
# Iteration 010: Energy = -25.278905, Var = 0.3129, LR = 5.00e-02
# Iteration 020: Energy = -25.312561, Var = 0.1852, LR = 5.00e-02
# Iteration 030: Energy = -25.306950, Var = 0.1423, LR = 5.00e-02
# Iteration 040: Energy = -25.306220, Var = 0.1146, LR = 5.00e-02
# Iteration 050: Energy = -25.318445, Var = 0.1000, LR = 5.00e-02
# Iteration 060: Energy = -25.335341, Var = 0.0914, LR = 5.00e-02
# Iteration 070: Energy = -25.323754, Var = 0.0780, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 073: Energy stalled at -25.328701
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 080: Energy = -25.322971, Var = 0.0728, LR = 2.50e-02
# Iteration 090: Energy = -25.328702, Var = 0.0682, LR = 2.50e-02
# Iteration 100: Energy = -25.337951, Var = 0.0625, LR = 2.50e-02
# Iteration 110: Energy = -25.323390, Var = 0.0599, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 112: Energy stalled at -25.333136
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 120: Energy = -25.339488, Var = 0.0594, LR = 1.25e-02
# Iteration 130: Energy = -25.325093, Var = 0.0560, LR = 1.25e-02
# Iteration 140: Energy = -25.343549, Var = 0.0562, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 142: Energy stalled at -25.333407
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 150: Energy = -25.341388, Var = 0.0540, LR = 6.25e-03
# Iteration 160: Energy = -25.334870, Var = 0.0514, LR = 6.25e-03
# Iteration 170: Energy = -25.322460, Var = 0.0513, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 172: Energy stalled at -25.342872
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 180: Energy = -25.343054, Var = 0.0541, LR = 3.13e-03
#
# ============================================================
#  >>> [EARLY STOPPING] Step 182: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 082 (Energy: -25.347117)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88def76a0> requested to stop the run.
#
# Restored best model weights from step 082 (Energy: -25.347117)
#
# Relative error   : 0.00017849763146215064
#
# ========================================
# Mean Energy:        -25.338040
# Error Bar:          ± 0.006060
# Variance:           0.073721
# Final VMC Energy:   -25.331171
# Energy per Fermion: -1.055752
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=5678/seed=202/rbm_alpha=1_ML_final_params.mpack
# Time taken = 20.295523166656494 (secs)
# ===================================================================================
# Current seed_nqs=303
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -24.019933, Var = 5.0535, LR = 5.00e-02
# Iteration 010: Energy = -25.281267, Var = 0.3092, LR = 5.00e-02
# Iteration 020: Energy = -25.307170, Var = 0.1944, LR = 5.00e-02
# Iteration 030: Energy = -25.328708, Var = 0.1369, LR = 5.00e-02
# Iteration 040: Energy = -25.321035, Var = 0.1056, LR = 5.00e-02
# Iteration 050: Energy = -25.319120, Var = 0.0946, LR = 5.00e-02
# Iteration 060: Energy = -25.319463, Var = 0.0875, LR = 5.00e-02
# Iteration 070: Energy = -25.330202, Var = 0.0762, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 075: Energy stalled at -25.335180
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 080: Energy = -25.336934, Var = 0.0705, LR = 2.50e-02
# Iteration 090: Energy = -25.334552, Var = 0.0678, LR = 2.50e-02
# Iteration 100: Energy = -25.326746, Var = 0.0583, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 105: Energy stalled at -25.334845
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 110: Energy = -25.334467, Var = 0.0588, LR = 1.25e-02
# Iteration 120: Energy = -25.332096, Var = 0.0581, LR = 1.25e-02
# Iteration 130: Energy = -25.333071, Var = 0.0558, LR = 1.25e-02
# Iteration 140: Energy = -25.335200, Var = 0.0572, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 144: Energy stalled at -25.340364
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 150: Energy = -25.341439, Var = 0.0535, LR = 6.25e-03
# Iteration 160: Energy = -25.338333, Var = 0.0519, LR = 6.25e-03
# Iteration 170: Energy = -25.334974, Var = 0.0545, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 174: Energy stalled at -25.338759
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 180: Energy = -25.337433, Var = 0.0499, LR = 3.13e-03
# Iteration 190: Energy = -25.338042, Var = 0.0508, LR = 3.13e-03
# Iteration 200: Energy = -25.339674, Var = 0.0510, LR = 3.13e-03
# Iteration 210: Energy = -25.333103, Var = 0.0500, LR = 3.13e-03
# Iteration 220: Energy = -25.322627, Var = 0.0487, LR = 3.13e-03
# Iteration 230: Energy = -25.337729, Var = 0.0482, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 235: Energy stalled at -25.338602
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 240: Energy = -25.338429, Var = 0.0496, LR = 1.56e-03
# Iteration 250: Energy = -25.340961, Var = 0.0481, LR = 1.56e-03
# Iteration 260: Energy = -25.338514, Var = 0.0490, LR = 1.56e-03
# Iteration 270: Energy = -25.337164, Var = 0.0482, LR = 1.56e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 272: Energy stalled at -25.340196
#  >>> Lowering LR: 1.56e-03 --> 7.81e-04
# =======================================================
#
# Iteration 280: Energy = -25.341663, Var = 0.0473, LR = 7.81e-04
# Iteration 290: Energy = -25.330203, Var = 0.0477, LR = 7.81e-04
# Iteration 300: Energy = -25.331892, Var = 0.0493, LR = 7.81e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 302: Energy stalled at -25.329415
#  >>> Lowering LR: 7.81e-04 --> 3.91e-04
# =======================================================
#
# Iteration 310: Energy = -25.331693, Var = 0.0491, LR = 3.91e-04
# Iteration 320: Energy = -25.332532, Var = 0.0486, LR = 3.91e-04
# Iteration 330: Energy = -25.343699, Var = 0.0495, LR = 3.91e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 332: Energy stalled at -25.330991
#  >>> Lowering LR: 3.91e-04 --> 1.95e-04
# =======================================================
#
# Iteration 340: Energy = -25.330298, Var = 0.0511, LR = 1.95e-04
# Iteration 350: Energy = -25.340216, Var = 0.0455, LR = 1.95e-04
# Iteration 360: Energy = -25.336528, Var = 0.0484, LR = 1.95e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 363: Energy stalled at -25.338697
#  >>> Lowering LR: 1.95e-04 --> 9.77e-05
# =======================================================
#
# Iteration 370: Energy = -25.341596, Var = 0.0449, LR = 9.77e-05
# Iteration 380: Energy = -25.335686, Var = 0.0512, LR = 9.77e-05
# Iteration 390: Energy = -25.338998, Var = 0.0474, LR = 9.77e-05
#
# =======================================================
#  >>> [LR REDUCTION] Step 393: Energy stalled at -25.339158
#  >>> Lowering LR: 9.77e-05 --> 4.88e-05
# =======================================================
#
# Iteration 400: Energy = -25.342524, Var = 0.0493, LR = 4.88e-05
# Iteration 410: Energy = -25.334347, Var = 0.0486, LR = 4.88e-05
# Iteration 420: Energy = -25.327378, Var = 0.0493, LR = 4.88e-05
#
# =======================================================
#  >>> [LR REDUCTION] Step 423: Energy stalled at -25.332666
#  >>> Lowering LR: 4.88e-05 --> 2.44e-05
# =======================================================
#
# Iteration 430: Energy = -25.337778, Var = 0.0469, LR = 2.44e-05
#
# ============================================================
#  >>> [EARLY STOPPING] Step 433: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 333 (Energy: -25.348298)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88c8b7b00> requested to stop the run.
#
# Restored best model weights from step 333 (Energy: -25.348298)
#
# Relative error   : 0.0002251150532937642
#
# ========================================
# Mean Energy:        -25.334705
# Error Bar:          ± 0.004770
# Variance:           0.049492
# Final VMC Energy:   -25.345280
# Energy per Fermion: -1.055613
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=5678/seed=303/rbm_alpha=1_ML_final_params.mpack
# Time taken = 47.45202088356018 (secs)
# ===================================================================================
# ********************************************************************************
# Current seed_qsk=9012
# Generating N=24 exact ground state on CPU RAM...
# Sparse matrix constructed (16777216x16777216). Diagonalizing via SciPy ARPACK...
# Exact GS saved to sk_ground_state_N=24_seed=9012.npy. Energy = -26.044812
# Exact ED Ground State Energy for seed 9012 is -26.044812
# ********************************************************************************
# Current seed_nqs=101
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.996365, Var = 6.1970, LR = 5.00e-02
# Iteration 010: Energy = -25.926261, Var = 0.4600, LR = 5.00e-02
# Iteration 020: Energy = -26.017650, Var = 0.1934, LR = 5.00e-02
# Iteration 030: Energy = -26.014529, Var = 0.1406, LR = 5.00e-02
# Iteration 040: Energy = -26.020083, Var = 0.1085, LR = 5.00e-02
# Iteration 050: Energy = -26.020557, Var = 0.0883, LR = 5.00e-02
# Iteration 060: Energy = -26.036919, Var = 0.0895, LR = 5.00e-02
# Iteration 070: Energy = -26.031669, Var = 0.0813, LR = 5.00e-02
# Iteration 080: Energy = -26.036276, Var = 0.0771, LR = 5.00e-02
# Iteration 090: Energy = -26.030118, Var = 0.0699, LR = 5.00e-02
# Iteration 100: Energy = -26.035016, Var = 0.0627, LR = 5.00e-02
# Iteration 110: Energy = -26.045807, Var = 0.0561, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 115: Energy stalled at -26.032333
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 120: Energy = -26.032617, Var = 0.0532, LR = 2.50e-02
# Iteration 130: Energy = -26.028588, Var = 0.0498, LR = 2.50e-02
# Iteration 140: Energy = -26.044371, Var = 0.0496, LR = 2.50e-02
# Iteration 150: Energy = -26.040412, Var = 0.0477, LR = 2.50e-02
# Iteration 160: Energy = -26.045298, Var = 0.0470, LR = 2.50e-02
# Iteration 170: Energy = -26.037697, Var = 0.0449, LR = 2.50e-02
# Iteration 180: Energy = -26.034980, Var = 0.0443, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 184: Energy stalled at -26.032445
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 190: Energy = -26.035522, Var = 0.0422, LR = 1.25e-02
# Iteration 200: Energy = -26.047791, Var = 0.0438, LR = 1.25e-02
# Iteration 210: Energy = -26.039628, Var = 0.0429, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 214: Energy stalled at -26.041872
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 220: Energy = -26.040553, Var = 0.0399, LR = 6.25e-03
# Iteration 230: Energy = -26.042374, Var = 0.0417, LR = 6.25e-03
# Iteration 240: Energy = -26.034416, Var = 0.0404, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 244: Energy stalled at -26.038813
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 250: Energy = -26.038177, Var = 0.0419, LR = 3.13e-03
#
# ============================================================
#  >>> [EARLY STOPPING] Step 254: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 154 (Energy: -26.051761)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88dc271a0> requested to stop the run.
#
# Restored best model weights from step 154 (Energy: -26.051761)
#
# Relative error   : 0.00026681977239245485
#
# ========================================
# Mean Energy:        -26.046311
# Error Bar:          ± 0.005023
# Variance:           0.049413
# Final VMC Energy:   -26.038424
# Energy per Fermion: -1.085263
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=9012/seed=101/rbm_alpha=1_ML_final_params.mpack
# Time taken = 28.729666709899902 (secs)
# ===================================================================================
# Current seed_nqs=202
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -24.113611, Var = 6.7719, LR = 5.00e-02
# Iteration 010: Energy = -25.926186, Var = 0.4904, LR = 5.00e-02
# Iteration 020: Energy = -26.015465, Var = 0.2275, LR = 5.00e-02
# Iteration 030: Energy = -26.022311, Var = 0.1593, LR = 5.00e-02
# Iteration 040: Energy = -26.029903, Var = 0.1271, LR = 5.00e-02
# Iteration 050: Energy = -26.031486, Var = 0.1176, LR = 5.00e-02
# Iteration 060: Energy = -26.024717, Var = 0.1075, LR = 5.00e-02
# Iteration 070: Energy = -26.030599, Var = 0.0977, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 076: Energy stalled at -26.029728
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 080: Energy = -26.032653, Var = 0.0881, LR = 2.50e-02
# Iteration 090: Energy = -26.027663, Var = 0.0893, LR = 2.50e-02
# Iteration 100: Energy = -26.026443, Var = 0.0805, LR = 2.50e-02
# Iteration 110: Energy = -26.046703, Var = 0.0786, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 117: Energy stalled at -26.025890
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 120: Energy = -26.034947, Var = 0.0772, LR = 1.25e-02
# Iteration 130: Energy = -26.030877, Var = 0.0726, LR = 1.25e-02
# Iteration 140: Energy = -26.037249, Var = 0.0714, LR = 1.25e-02
# Iteration 150: Energy = -26.032216, Var = 0.0699, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 152: Energy stalled at -26.038485
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 160: Energy = -26.037901, Var = 0.0756, LR = 6.25e-03
# Iteration 170: Energy = -26.031835, Var = 0.0698, LR = 6.25e-03
# Iteration 180: Energy = -26.028978, Var = 0.0693, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 182: Energy stalled at -26.025624
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 190: Energy = -26.029893, Var = 0.0630, LR = 3.13e-03
# Iteration 200: Energy = -26.037898, Var = 0.0668, LR = 3.13e-03
# Iteration 210: Energy = -26.034539, Var = 0.0666, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 212: Energy stalled at -26.040418
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 220: Energy = -26.039356, Var = 0.0666, LR = 1.56e-03
#
# ============================================================
#  >>> [EARLY STOPPING] Step 222: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 122 (Energy: -26.050004)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79fbb62e1080> requested to stop the run.
#
# Restored best model weights from step 122 (Energy: -26.050004)
#
# Relative error   : 0.00019936638582195655
#
# ========================================
# Mean Energy:        -26.033844
# Error Bar:          ± 0.006289
# Variance:           0.076581
# Final VMC Energy:   -26.028285
# Energy per Fermion: -1.084744
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=9012/seed=202/rbm_alpha=1_ML_final_params.mpack
# Time taken = 25.019427061080933 (secs)
# ===================================================================================
# Current seed_nqs=303
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.977217, Var = 6.8747, LR = 5.00e-02
# Iteration 010: Energy = -25.975742, Var = 0.4319, LR = 5.00e-02
# Iteration 020: Energy = -26.005284, Var = 0.1924, LR = 5.00e-02
# Iteration 030: Energy = -26.021988, Var = 0.1411, LR = 5.00e-02
# Iteration 040: Energy = -26.028405, Var = 0.1163, LR = 5.00e-02
# Iteration 050: Energy = -26.032177, Var = 0.1088, LR = 5.00e-02
# Iteration 060: Energy = -26.038463, Var = 0.0929, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 069: Energy stalled at -26.025706
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 070: Energy = -26.023771, Var = 0.0884, LR = 2.50e-02
# Iteration 080: Energy = -26.025177, Var = 0.0843, LR = 2.50e-02
# Iteration 090: Energy = -26.031143, Var = 0.0788, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 099: Energy stalled at -26.043506
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 100: Energy = -26.038150, Var = 0.0780, LR = 1.25e-02
# Iteration 110: Energy = -26.034327, Var = 0.0779, LR = 1.25e-02
# Iteration 120: Energy = -26.046678, Var = 0.0707, LR = 1.25e-02
# Iteration 130: Energy = -26.042322, Var = 0.0688, LR = 1.25e-02
# Iteration 140: Energy = -26.031726, Var = 0.0697, LR = 1.25e-02
# Iteration 150: Energy = -26.041355, Var = 0.0645, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 150: Energy stalled at -26.041355
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 160: Energy = -26.037976, Var = 0.0717, LR = 6.25e-03
# Iteration 170: Energy = -26.044931, Var = 0.0600, LR = 6.25e-03
# Iteration 180: Energy = -26.031103, Var = 0.0648, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 180: Energy stalled at -26.031103
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 190: Energy = -26.027083, Var = 0.0631, LR = 3.13e-03
# Iteration 200: Energy = -26.042366, Var = 0.0679, LR = 3.13e-03
# Iteration 210: Energy = -26.041075, Var = 0.0662, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 214: Energy stalled at -26.039226
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 220: Energy = -26.039898, Var = 0.0645, LR = 1.56e-03
# Iteration 230: Energy = -26.029661, Var = 0.0573, LR = 1.56e-03
# Iteration 240: Energy = -26.037291, Var = 0.0583, LR = 1.56e-03
# Iteration 250: Energy = -26.030574, Var = 0.0618, LR = 1.56e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 254: Energy stalled at -26.039268
#  >>> Lowering LR: 1.56e-03 --> 7.81e-04
# =======================================================
#
# Iteration 260: Energy = -26.042074, Var = 0.0667, LR = 7.81e-04
# Iteration 270: Energy = -26.033930, Var = 0.0591, LR = 7.81e-04
# Iteration 280: Energy = -26.032013, Var = 0.0598, LR = 7.81e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 284: Energy stalled at -26.043894
#  >>> Lowering LR: 7.81e-04 --> 3.91e-04
# =======================================================
#
# Iteration 290: Energy = -26.036858, Var = 0.0683, LR = 3.91e-04
# Iteration 300: Energy = -26.036441, Var = 0.0650, LR = 3.91e-04
# Iteration 310: Energy = -26.027407, Var = 0.0654, LR = 3.91e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 314: Energy stalled at -26.043548
#  >>> Lowering LR: 3.91e-04 --> 1.95e-04
# =======================================================
#
# Iteration 320: Energy = -26.036279, Var = 0.0647, LR = 1.95e-04
#
# ============================================================
#  >>> [EARLY STOPPING] Step 324: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 224 (Energy: -26.050687)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88dcabba0> requested to stop the run.
#
# Restored best model weights from step 224 (Energy: -26.050687)
#
# Relative error   : 0.00022559348126867919
#
# ========================================
# Mean Energy:        -26.045065
# Error Bar:          ± 0.005655
# Variance:           0.064571
# Final VMC Energy:   -26.032608
# Energy per Fermion: -1.085211
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=9012/seed=303/rbm_alpha=1_ML_final_params.mpack
# Time taken = 36.30289673805237 (secs)
# ===================================================================================

# %% [markdown]
# # HRBM

# %%
k=1.0
Lmax=20
for seed_qsk in seed_qsk_list:
    print('********************************************************************************')
    print(f'Current seed_qsk={seed_qsk}')
    hamiltonian, H = generate_hamiltonian_sk(N=N, seed=seed_qsk)
    _, ground_state_vec = generate_state_sk(N=N, seed=seed_qsk)
    #sp_h = H.to_sparse()
    sp_h = generate_hamiltonian_sk_scipy(N, seed_qsk)
    exact_E = (ground_state_vec.conj().T @ sp_h @ ground_state_vec).real
    print(f"Exact ED Ground State Energy for seed {seed_qsk} is {exact_E:.6f}")
    print('********************************************************************************')
    
    for seed_nqs in seed_nqs_list:
        print(f'Current seed_nqs={seed_nqs}')
        model = HyperbolicRBMd_Coupled(alpha=alpha, k=k, Lmax=Lmax)
        nqs_training(N, hamiltonian, exact_E, model, lr, alpha, n_samples, seed_nqs, 'hrbm')
        print('===================================================================================')
# Out:
# ********************************************************************************
# Current seed_qsk=1234
# Loading cached exact ground state from sk_ground_state_N=24_seed=1234.npy...
# Exact ED Ground State Energy for seed 1234 is -25.424855
# ********************************************************************************
# Current seed_nqs=101
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.929673, Var = 5.1006, LR = 5.00e-02
# Iteration 010: Energy = -25.404833, Var = 0.1039, LR = 5.00e-02
# Iteration 020: Energy = -25.415437, Var = 0.0561, LR = 5.00e-02
# Iteration 030: Energy = -25.417435, Var = 0.0504, LR = 5.00e-02
# Iteration 040: Energy = -25.411874, Var = 0.0475, LR = 5.00e-02
# Iteration 050: Energy = -25.413935, Var = 0.0465, LR = 5.00e-02
# Iteration 060: Energy = -25.422981, Var = 0.0466, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 065: Energy stalled at -25.421885
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 070: Energy = -25.421590, Var = 0.0420, LR = 2.50e-02
# Iteration 080: Energy = -25.420798, Var = 0.0451, LR = 2.50e-02
# Iteration 090: Energy = -25.418996, Var = 0.0426, LR = 2.50e-02
# Iteration 100: Energy = -25.420171, Var = 0.0404, LR = 2.50e-02
# Iteration 110: Energy = -25.416223, Var = 0.0411, LR = 2.50e-02
# Iteration 120: Energy = -25.415903, Var = 0.0378, LR = 2.50e-02
# Iteration 130: Energy = -25.419450, Var = 0.0384, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 138: Energy stalled at -25.422531
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 140: Energy = -25.426111, Var = 0.0396, LR = 1.25e-02
# Iteration 150: Energy = -25.421870, Var = 0.0413, LR = 1.25e-02
# Iteration 160: Energy = -25.418992, Var = 0.0377, LR = 1.25e-02
# Iteration 170: Energy = -25.422124, Var = 0.0398, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 177: Energy stalled at -25.412885
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 180: Energy = -25.423162, Var = 0.0392, LR = 6.25e-03
# Iteration 190: Energy = -25.423870, Var = 0.0398, LR = 6.25e-03
# Iteration 200: Energy = -25.418728, Var = 0.0388, LR = 6.25e-03
# Iteration 210: Energy = -25.418948, Var = 0.0352, LR = 6.25e-03
# Iteration 220: Energy = -25.423509, Var = 0.0378, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 221: Energy stalled at -25.426648
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 230: Energy = -25.419409, Var = 0.0375, LR = 3.13e-03
# Iteration 240: Energy = -25.413338, Var = 0.0353, LR = 3.13e-03
# Iteration 250: Energy = -25.419796, Var = 0.0350, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 251: Energy stalled at -25.417258
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 260: Energy = -25.424725, Var = 0.0372, LR = 1.56e-03
# Iteration 270: Energy = -25.421884, Var = 0.0368, LR = 1.56e-03
# Iteration 280: Energy = -25.422092, Var = 0.0381, LR = 1.56e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 281: Energy stalled at -25.419222
#  >>> Lowering LR: 1.56e-03 --> 7.81e-04
# =======================================================
#
# Iteration 290: Energy = -25.419805, Var = 0.0416, LR = 7.81e-04
#
# ============================================================
#  >>> [EARLY STOPPING] Step 291: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 191 (Energy: -25.429489)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88db81120> requested to stop the run.
#
# Restored best model weights from step 191 (Energy: -25.429489)
#
# Relative error   : 0.00018226961793404176
#
# ========================================
# Mean Energy:        -25.417227
# Error Bar:          ± 0.004383
# Variance:           0.039972
# Final VMC Energy:   -25.419805
# Energy per Fermion: -1.059051
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=1234/seed=101/hrbm_alpha=1_ML_final_params.mpack
# Time taken = 147.35463619232178 (secs)
# ===================================================================================
# Current seed_nqs=202
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.869766, Var = 5.3045, LR = 5.00e-02
# Iteration 010: Energy = -25.399437, Var = 0.1092, LR = 5.00e-02
# Iteration 020: Energy = -25.416665, Var = 0.0625, LR = 5.00e-02
# Iteration 030: Energy = -25.423962, Var = 0.0577, LR = 5.00e-02
# Iteration 040: Energy = -25.417726, Var = 0.0509, LR = 5.00e-02
# Iteration 050: Energy = -25.419799, Var = 0.0489, LR = 5.00e-02
# Iteration 060: Energy = -25.420805, Var = 0.0460, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 060: Energy stalled at -25.420805
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 070: Energy = -25.415805, Var = 0.0468, LR = 2.50e-02
# Iteration 080: Energy = -25.415909, Var = 0.0446, LR = 2.50e-02
# Iteration 090: Energy = -25.423581, Var = 0.0475, LR = 2.50e-02
# Iteration 100: Energy = -25.416303, Var = 0.0418, LR = 2.50e-02
# Iteration 110: Energy = -25.417549, Var = 0.0409, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 116: Energy stalled at -25.423648
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 120: Energy = -25.419821, Var = 0.0424, LR = 1.25e-02
# Iteration 130: Energy = -25.422797, Var = 0.0406, LR = 1.25e-02
# Iteration 140: Energy = -25.420564, Var = 0.0409, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 146: Energy stalled at -25.419343
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 150: Energy = -25.419015, Var = 0.0404, LR = 6.25e-03
# Iteration 160: Energy = -25.415348, Var = 0.0395, LR = 6.25e-03
# Iteration 170: Energy = -25.414505, Var = 0.0393, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 177: Energy stalled at -25.423041
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 180: Energy = -25.420295, Var = 0.0389, LR = 3.13e-03
# Iteration 190: Energy = -25.421470, Var = 0.0402, LR = 3.13e-03
# Iteration 200: Energy = -25.426118, Var = 0.0424, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 207: Energy stalled at -25.421954
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 210: Energy = -25.416162, Var = 0.0403, LR = 1.56e-03
# Iteration 220: Energy = -25.414073, Var = 0.0389, LR = 1.56e-03
# Iteration 230: Energy = -25.416799, Var = 0.0366, LR = 1.56e-03
# Iteration 240: Energy = -25.421930, Var = 0.0394, LR = 1.56e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 242: Energy stalled at -25.415493
#  >>> Lowering LR: 1.56e-03 --> 7.81e-04
# =======================================================
#
# Iteration 250: Energy = -25.421995, Var = 0.0399, LR = 7.81e-04
# Iteration 260: Energy = -25.420615, Var = 0.0406, LR = 7.81e-04
# Iteration 270: Energy = -25.416006, Var = 0.0410, LR = 7.81e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 272: Energy stalled at -25.412793
#  >>> Lowering LR: 7.81e-04 --> 3.91e-04
# =======================================================
#
# Iteration 280: Energy = -25.413847, Var = 0.0403, LR = 3.91e-04
# Iteration 290: Energy = -25.418408, Var = 0.0368, LR = 3.91e-04
# Iteration 300: Energy = -25.418454, Var = 0.0404, LR = 3.91e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 302: Energy stalled at -25.420195
#  >>> Lowering LR: 3.91e-04 --> 1.95e-04
# =======================================================
#
# Iteration 310: Energy = -25.416934, Var = 0.0388, LR = 1.95e-04
#
# ============================================================
#  >>> [EARLY STOPPING] Step 312: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 212 (Energy: -25.428858)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88dca84a0> requested to stop the run.
#
# Restored best model weights from step 212 (Energy: -25.428858)
#
# Relative error   : 0.00015744892341890517
#
# ========================================
# Mean Energy:        -25.417555
# Error Bar:          ± 0.004575
# Variance:           0.042092
# Final VMC Energy:   -25.426259
# Energy per Fermion: -1.059065
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=1234/seed=202/hrbm_alpha=1_ML_final_params.mpack
# Time taken = 116.5122561454773 (secs)
# ===================================================================================
# Current seed_nqs=303
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.730918, Var = 5.6527, LR = 5.00e-02
# Iteration 010: Energy = -25.387287, Var = 0.1086, LR = 5.00e-02
# Iteration 020: Energy = -25.416166, Var = 0.0589, LR = 5.00e-02
# Iteration 030: Energy = -25.409787, Var = 0.0549, LR = 5.00e-02
# Iteration 040: Energy = -25.415002, Var = 0.0506, LR = 5.00e-02
# Iteration 050: Energy = -25.415091, Var = 0.0524, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 052: Energy stalled at -25.415074
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 060: Energy = -25.414032, Var = 0.0508, LR = 2.50e-02
# Iteration 070: Energy = -25.417959, Var = 0.0489, LR = 2.50e-02
# Iteration 080: Energy = -25.421608, Var = 0.0478, LR = 2.50e-02
# Iteration 090: Energy = -25.426664, Var = 0.0500, LR = 2.50e-02
# Iteration 100: Energy = -25.426792, Var = 0.0494, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 108: Energy stalled at -25.420627
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 110: Energy = -25.424066, Var = 0.0489, LR = 1.25e-02
# Iteration 120: Energy = -25.424762, Var = 0.0491, LR = 1.25e-02
# Iteration 130: Energy = -25.416932, Var = 0.0439, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 138: Energy stalled at -25.414312
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 140: Energy = -25.418176, Var = 0.0460, LR = 6.25e-03
# Iteration 150: Energy = -25.422110, Var = 0.0453, LR = 6.25e-03
# Iteration 160: Energy = -25.416944, Var = 0.0415, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 168: Energy stalled at -25.420976
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 170: Energy = -25.419271, Var = 0.0433, LR = 3.13e-03
#
# ============================================================
#  >>> [EARLY STOPPING] Step 178: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 078 (Energy: -25.429178)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88dcab7e0> requested to stop the run.
#
# Restored best model weights from step 078 (Energy: -25.429178)
#
# Relative error   : 0.00017006687997635824
#
# ========================================
# Mean Energy:        -25.411003
# Error Bar:          ± 0.004864
# Variance:           0.046300
# Final VMC Energy:   -25.413948
# Energy per Fermion: -1.058792
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=1234/seed=303/hrbm_alpha=1_ML_final_params.mpack
# Time taken = 66.51103854179382 (secs)
# ===================================================================================
# ********************************************************************************
# Current seed_qsk=5678
# Loading cached exact ground state from sk_ground_state_N=24_seed=5678.npy...
# Exact ED Ground State Energy for seed 5678 is -25.342593
# ********************************************************************************
# Current seed_nqs=101
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.867250, Var = 5.3337, LR = 5.00e-02
# Iteration 010: Energy = -25.338824, Var = 0.1100, LR = 5.00e-02
# Iteration 020: Energy = -25.332939, Var = 0.0678, LR = 5.00e-02
# Iteration 030: Energy = -25.336264, Var = 0.0580, LR = 5.00e-02
# Iteration 040: Energy = -25.333854, Var = 0.0560, LR = 5.00e-02
# Iteration 050: Energy = -25.337705, Var = 0.0570, LR = 5.00e-02
# Iteration 060: Energy = -25.332235, Var = 0.0648, LR = 5.00e-02
# Iteration 070: Energy = -25.336062, Var = 0.0519, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 076: Energy stalled at -25.339240
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 080: Energy = -25.330302, Var = 0.0513, LR = 2.50e-02
# Iteration 090: Energy = -25.333262, Var = 0.0499, LR = 2.50e-02
# Iteration 100: Energy = -25.325446, Var = 0.0510, LR = 2.50e-02
# Iteration 110: Energy = -25.334034, Var = 0.0462, LR = 2.50e-02
# Iteration 120: Energy = -25.336625, Var = 0.0495, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 123: Energy stalled at -25.334385
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 130: Energy = -25.330405, Var = 0.0471, LR = 1.25e-02
# Iteration 140: Energy = -25.343235, Var = 0.0482, LR = 1.25e-02
# Iteration 150: Energy = -25.334023, Var = 0.0447, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 153: Energy stalled at -25.333648
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 160: Energy = -25.339819, Var = 0.0500, LR = 6.25e-03
# Iteration 170: Energy = -25.332350, Var = 0.0459, LR = 6.25e-03
# Iteration 180: Energy = -25.339392, Var = 0.0469, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 183: Energy stalled at -25.339882
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 190: Energy = -25.334136, Var = 0.0465, LR = 3.13e-03
#
# ============================================================
#  >>> [EARLY STOPPING] Step 193: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 093 (Energy: -25.347600)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88c3b3ba0> requested to stop the run.
#
# Restored best model weights from step 093 (Energy: -25.347600)
#
# Relative error   : 0.00019756742554530166
#
# ========================================
# Mean Energy:        -25.336973
# Error Bar:          ± 0.004985
# Variance:           0.048606
# Final VMC Energy:   -25.334897
# Energy per Fermion: -1.055707
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=5678/seed=101/hrbm_alpha=1_ML_final_params.mpack
# Time taken = 70.70412516593933 (secs)
# ===================================================================================
# Current seed_nqs=202
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.854165, Var = 5.9693, LR = 5.00e-02
# Iteration 010: Energy = -25.304372, Var = 0.0901, LR = 5.00e-02
# Iteration 020: Energy = -25.329599, Var = 0.0622, LR = 5.00e-02
# Iteration 030: Energy = -25.334252, Var = 0.0642, LR = 5.00e-02
# Iteration 040: Energy = -25.342123, Var = 0.0577, LR = 5.00e-02
# Iteration 050: Energy = -25.336558, Var = 0.0595, LR = 5.00e-02
# Iteration 060: Energy = -25.333833, Var = 0.0586, LR = 5.00e-02
# Iteration 070: Energy = -25.340494, Var = 0.0547, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 070: Energy stalled at -25.340494
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 080: Energy = -25.333972, Var = 0.0524, LR = 2.50e-02
# Iteration 090: Energy = -25.339589, Var = 0.0523, LR = 2.50e-02
# Iteration 100: Energy = -25.334778, Var = 0.0501, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 100: Energy stalled at -25.334778
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 110: Energy = -25.335009, Var = 0.0509, LR = 1.25e-02
# Iteration 120: Energy = -25.334806, Var = 0.0491, LR = 1.25e-02
# Iteration 130: Energy = -25.334053, Var = 0.0522, LR = 1.25e-02
# Iteration 140: Energy = -25.331767, Var = 0.0480, LR = 1.25e-02
# Iteration 150: Energy = -25.341230, Var = 0.0524, LR = 1.25e-02
# Iteration 160: Energy = -25.335207, Var = 0.0505, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 161: Energy stalled at -25.336239
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 170: Energy = -25.333579, Var = 0.0465, LR = 6.25e-03
# Iteration 180: Energy = -25.339448, Var = 0.0501, LR = 6.25e-03
# Iteration 190: Energy = -25.334816, Var = 0.0487, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 191: Energy stalled at -25.334481
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 200: Energy = -25.338996, Var = 0.0526, LR = 3.13e-03
# Iteration 210: Energy = -25.339351, Var = 0.0489, LR = 3.13e-03
# Iteration 220: Energy = -25.329695, Var = 0.0500, LR = 3.13e-03
# Iteration 230: Energy = -25.337785, Var = 0.0505, LR = 3.13e-03
# Iteration 240: Energy = -25.339603, Var = 0.0473, LR = 3.13e-03
# Iteration 250: Energy = -25.332668, Var = 0.0501, LR = 3.13e-03
# Iteration 260: Energy = -25.337169, Var = 0.0457, LR = 3.13e-03
# Iteration 270: Energy = -25.336317, Var = 0.0488, LR = 3.13e-03
# Iteration 280: Energy = -25.337780, Var = 0.0479, LR = 3.13e-03
# Iteration 290: Energy = -25.338940, Var = 0.0467, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 293: Energy stalled at -25.339009
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 300: Energy = -25.329949, Var = 0.0509, LR = 1.56e-03
# Iteration 310: Energy = -25.337337, Var = 0.0445, LR = 1.56e-03
# Iteration 320: Energy = -25.330957, Var = 0.0447, LR = 1.56e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 323: Energy stalled at -25.334590
#  >>> Lowering LR: 1.56e-03 --> 7.81e-04
# =======================================================
#
# Iteration 330: Energy = -25.333366, Var = 0.0475, LR = 7.81e-04
# Iteration 340: Energy = -25.335855, Var = 0.0533, LR = 7.81e-04
# Iteration 350: Energy = -25.339945, Var = 0.0523, LR = 7.81e-04
# Iteration 360: Energy = -25.339145, Var = 0.0519, LR = 7.81e-04
# Iteration 370: Energy = -25.340409, Var = 0.0512, LR = 7.81e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 371: Energy stalled at -25.341919
#  >>> Lowering LR: 7.81e-04 --> 3.91e-04
# =======================================================
#
# Iteration 380: Energy = -25.329255, Var = 0.0461, LR = 3.91e-04
# Iteration 390: Energy = -25.333887, Var = 0.0496, LR = 3.91e-04
# Iteration 400: Energy = -25.339720, Var = 0.0487, LR = 3.91e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 401: Energy stalled at -25.337313
#  >>> Lowering LR: 3.91e-04 --> 1.95e-04
# =======================================================
#
# Iteration 410: Energy = -25.336393, Var = 0.0479, LR = 1.95e-04
# Iteration 420: Energy = -25.338152, Var = 0.0453, LR = 1.95e-04
# Iteration 430: Energy = -25.336625, Var = 0.0477, LR = 1.95e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 431: Energy stalled at -25.337220
#  >>> Lowering LR: 1.95e-04 --> 9.77e-05
# =======================================================
#
# Iteration 440: Energy = -25.345040, Var = 0.0485, LR = 9.77e-05
#
# ============================================================
#  >>> [EARLY STOPPING] Step 441: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 341 (Energy: -25.347010)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88d6ffce0> requested to stop the run.
#
# Restored best model weights from step 341 (Energy: -25.347010)
#
# Relative error   : 0.00017427973899981225
#
# ========================================
# Mean Energy:        -25.335196
# Error Bar:          ± 0.005046
# Variance:           0.050152
# Final VMC Energy:   -25.345040
# Energy per Fermion: -1.055633
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=5678/seed=202/hrbm_alpha=1_ML_final_params.mpack
# Time taken = 159.9664101600647 (secs)
# ===================================================================================
# Current seed_nqs=303
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.894194, Var = 5.5928, LR = 5.00e-02
# Iteration 010: Energy = -25.327274, Var = 0.1053, LR = 5.00e-02
# Iteration 020: Energy = -25.335582, Var = 0.0728, LR = 5.00e-02
# Iteration 030: Energy = -25.331825, Var = 0.0601, LR = 5.00e-02
# Iteration 040: Energy = -25.332985, Var = 0.0621, LR = 5.00e-02
# Iteration 050: Energy = -25.337347, Var = 0.0579, LR = 5.00e-02
# Iteration 060: Energy = -25.332094, Var = 0.0544, LR = 5.00e-02
# Iteration 070: Energy = -25.339942, Var = 0.0562, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 071: Energy stalled at -25.334928
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 080: Energy = -25.334934, Var = 0.0543, LR = 2.50e-02
# Iteration 090: Energy = -25.330661, Var = 0.0546, LR = 2.50e-02
# Iteration 100: Energy = -25.329503, Var = 0.0524, LR = 2.50e-02
# Iteration 110: Energy = -25.337893, Var = 0.0509, LR = 2.50e-02
# Iteration 120: Energy = -25.339206, Var = 0.0488, LR = 2.50e-02
# Iteration 130: Energy = -25.340379, Var = 0.0523, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 135: Energy stalled at -25.336410
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 140: Energy = -25.334662, Var = 0.0476, LR = 1.25e-02
# Iteration 150: Energy = -25.334906, Var = 0.0480, LR = 1.25e-02
# Iteration 160: Energy = -25.338766, Var = 0.0463, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 165: Energy stalled at -25.341523
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 170: Energy = -25.335038, Var = 0.0455, LR = 6.25e-03
# Iteration 180: Energy = -25.339042, Var = 0.0526, LR = 6.25e-03
# Iteration 190: Energy = -25.334089, Var = 0.0482, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 195: Energy stalled at -25.332435
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 200: Energy = -25.335929, Var = 0.0534, LR = 3.13e-03
#
# ============================================================
#  >>> [EARLY STOPPING] Step 205: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 105 (Energy: -25.344866)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88c3b22a0> requested to stop the run.
#
# Restored best model weights from step 105 (Energy: -25.344866)
#
# Relative error   : 8.968322615045944e-05
#
# ========================================
# Mean Energy:        -25.339588
# Error Bar:          ± 0.005184
# Variance:           0.052640
# Final VMC Energy:   -25.336740
# Energy per Fermion: -1.055816
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=5678/seed=303/hrbm_alpha=1_ML_final_params.mpack
# Time taken = 75.54058384895325 (secs)
# ===================================================================================
# ********************************************************************************
# Current seed_qsk=9012
# Loading cached exact ground state from sk_ground_state_N=24_seed=9012.npy...
# Exact ED Ground State Energy for seed 9012 is -26.044812
# ********************************************************************************
# Current seed_nqs=101
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.828275, Var = 6.9217, LR = 5.00e-02
# Iteration 010: Energy = -25.968480, Var = 0.2084, LR = 5.00e-02
# Iteration 020: Energy = -26.023177, Var = 0.0931, LR = 5.00e-02
# Iteration 030: Energy = -26.031058, Var = 0.0714, LR = 5.00e-02
# Iteration 040: Energy = -26.047314, Var = 0.0645, LR = 5.00e-02
# Iteration 050: Energy = -26.036364, Var = 0.0556, LR = 5.00e-02
# Iteration 060: Energy = -26.036421, Var = 0.0555, LR = 5.00e-02
# Iteration 070: Energy = -26.034394, Var = 0.0528, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 070: Energy stalled at -26.034394
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 080: Energy = -26.037351, Var = 0.0498, LR = 2.50e-02
# Iteration 090: Energy = -26.030455, Var = 0.0472, LR = 2.50e-02
# Iteration 100: Energy = -26.036092, Var = 0.0443, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 100: Energy stalled at -26.036092
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 110: Energy = -26.042614, Var = 0.0470, LR = 1.25e-02
# Iteration 120: Energy = -26.041006, Var = 0.0462, LR = 1.25e-02
# Iteration 130: Energy = -26.042156, Var = 0.0464, LR = 1.25e-02
# Iteration 140: Energy = -26.040943, Var = 0.0470, LR = 1.25e-02
# Iteration 150: Energy = -26.039324, Var = 0.0443, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 158: Energy stalled at -26.044835
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 160: Energy = -26.038871, Var = 0.0447, LR = 6.25e-03
# Iteration 170: Energy = -26.039533, Var = 0.0436, LR = 6.25e-03
# Iteration 180: Energy = -26.041879, Var = 0.0400, LR = 6.25e-03
# Iteration 190: Energy = -26.042931, Var = 0.0463, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 191: Energy stalled at -26.040307
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 200: Energy = -26.043743, Var = 0.0441, LR = 3.13e-03
# Iteration 210: Energy = -26.043744, Var = 0.0433, LR = 3.13e-03
# Iteration 220: Energy = -26.045443, Var = 0.0465, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 221: Energy stalled at -26.036083
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 230: Energy = -26.033612, Var = 0.0431, LR = 1.56e-03
# Iteration 240: Energy = -26.041082, Var = 0.0470, LR = 1.56e-03
# Iteration 250: Energy = -26.046722, Var = 0.0457, LR = 1.56e-03
# Iteration 260: Energy = -26.033993, Var = 0.0414, LR = 1.56e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 269: Energy stalled at -26.040298
#  >>> Lowering LR: 1.56e-03 --> 7.81e-04
# =======================================================
#
# Iteration 270: Energy = -26.042347, Var = 0.0424, LR = 7.81e-04
# Iteration 280: Energy = -26.040763, Var = 0.0431, LR = 7.81e-04
# Iteration 290: Energy = -26.040433, Var = 0.0456, LR = 7.81e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 299: Energy stalled at -26.038467
#  >>> Lowering LR: 7.81e-04 --> 3.91e-04
# =======================================================
#
# Iteration 300: Energy = -26.044855, Var = 0.0423, LR = 3.91e-04
# Iteration 310: Energy = -26.044758, Var = 0.0427, LR = 3.91e-04
# Iteration 320: Energy = -26.033722, Var = 0.0442, LR = 3.91e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 329: Energy stalled at -26.037245
#  >>> Lowering LR: 3.91e-04 --> 1.95e-04
# =======================================================
#
# Iteration 330: Energy = -26.038430, Var = 0.0433, LR = 1.95e-04
#
# ============================================================
#  >>> [EARLY STOPPING] Step 339: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 239 (Energy: -26.050264)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88de5b7e0> requested to stop the run.
#
# Restored best model weights from step 239 (Energy: -26.050264)
#
# Relative error   : 0.0002093539288407001
#
# ========================================
# Mean Energy:        -26.039708
# Error Bar:          ± 0.004848
# Variance:           0.046913
# Final VMC Energy:   -26.038097
# Energy per Fermion: -1.084988
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=9012/seed=101/hrbm_alpha=1_ML_final_params.mpack
# Time taken = 129.71941590309143 (secs)
# ===================================================================================
# Current seed_nqs=202
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.957013, Var = 6.8128, LR = 5.00e-02
# Iteration 010: Energy = -25.972418, Var = 0.1919, LR = 5.00e-02
# Iteration 020: Energy = -26.026065, Var = 0.0957, LR = 5.00e-02
# Iteration 030: Energy = -26.028984, Var = 0.0710, LR = 5.00e-02
# Iteration 040: Energy = -26.035015, Var = 0.0587, LR = 5.00e-02
# Iteration 050: Energy = -26.032107, Var = 0.0554, LR = 5.00e-02
# Iteration 060: Energy = -26.044937, Var = 0.0521, LR = 5.00e-02
# Iteration 070: Energy = -26.040830, Var = 0.0490, LR = 5.00e-02
# Iteration 080: Energy = -26.040286, Var = 0.0455, LR = 5.00e-02
# Iteration 090: Energy = -26.038802, Var = 0.0422, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 095: Energy stalled at -26.035000
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 100: Energy = -26.044707, Var = 0.0429, LR = 2.50e-02
# Iteration 110: Energy = -26.038165, Var = 0.0441, LR = 2.50e-02
# Iteration 120: Energy = -26.042710, Var = 0.0394, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 125: Energy stalled at -26.044746
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 130: Energy = -26.046625, Var = 0.0444, LR = 1.25e-02
# Iteration 140: Energy = -26.041273, Var = 0.0400, LR = 1.25e-02
# Iteration 150: Energy = -26.038563, Var = 0.0397, LR = 1.25e-02
# Iteration 160: Energy = -26.043709, Var = 0.0435, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 160: Energy stalled at -26.043709
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 170: Energy = -26.035444, Var = 0.0385, LR = 6.25e-03
# Iteration 180: Energy = -26.032256, Var = 0.0391, LR = 6.25e-03
# Iteration 190: Energy = -26.044935, Var = 0.0413, LR = 6.25e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 190: Energy stalled at -26.044935
#  >>> Lowering LR: 6.25e-03 --> 3.13e-03
# =======================================================
#
# Iteration 200: Energy = -26.045785, Var = 0.0395, LR = 3.13e-03
# Iteration 210: Energy = -26.041401, Var = 0.0394, LR = 3.13e-03
# Iteration 220: Energy = -26.042210, Var = 0.0423, LR = 3.13e-03
# Iteration 230: Energy = -26.031217, Var = 0.0394, LR = 3.13e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 236: Energy stalled at -26.031823
#  >>> Lowering LR: 3.13e-03 --> 1.56e-03
# =======================================================
#
# Iteration 240: Energy = -26.040663, Var = 0.0374, LR = 1.56e-03
# Iteration 250: Energy = -26.039845, Var = 0.0406, LR = 1.56e-03
# Iteration 260: Energy = -26.040527, Var = 0.0402, LR = 1.56e-03
#
# =======================================================
#  >>> [LR REDUCTION] Step 266: Energy stalled at -26.033548
#  >>> Lowering LR: 1.56e-03 --> 7.81e-04
# =======================================================
#
# Iteration 270: Energy = -26.030491, Var = 0.0392, LR = 7.81e-04
# Iteration 280: Energy = -26.037661, Var = 0.0378, LR = 7.81e-04
# Iteration 290: Energy = -26.035941, Var = 0.0430, LR = 7.81e-04
#
# =======================================================
#  >>> [LR REDUCTION] Step 296: Energy stalled at -26.039460
#  >>> Lowering LR: 7.81e-04 --> 3.91e-04
# =======================================================
#
# Iteration 300: Energy = -26.040146, Var = 0.0419, LR = 3.91e-04
#
# ============================================================
#  >>> [EARLY STOPPING] Step 306: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 206 (Energy: -26.048305)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88d843ec0> requested to stop the run.
#
# Restored best model weights from step 206 (Energy: -26.048305)
#
# Relative error   : 0.00013413017877783956
#
# ========================================
# Mean Energy:        -26.044270
# Error Bar:          ± 0.004474
# Variance:           0.039995
# Final VMC Energy:   -26.041762
# Energy per Fermion: -1.085178
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=9012/seed=202/hrbm_alpha=1_ML_final_params.mpack
# Time taken = 117.76723027229309 (secs)
# ===================================================================================
# Current seed_nqs=303
# Has 624 parameters
#   0%|          | 0/450 [00:00<?, ?it/s]
# Iteration 000: Energy = -23.763908, Var = 6.7508, LR = 5.00e-02
# Iteration 010: Energy = -25.977800, Var = 0.1906, LR = 5.00e-02
# Iteration 020: Energy = -26.027366, Var = 0.0779, LR = 5.00e-02
# Iteration 030: Energy = -26.039172, Var = 0.0670, LR = 5.00e-02
# Iteration 040: Energy = -26.037594, Var = 0.0652, LR = 5.00e-02
# Iteration 050: Energy = -26.043473, Var = 0.0558, LR = 5.00e-02
# Iteration 060: Energy = -26.034176, Var = 0.0550, LR = 5.00e-02
# Iteration 070: Energy = -26.041282, Var = 0.0526, LR = 5.00e-02
# Iteration 080: Energy = -26.033447, Var = 0.0507, LR = 5.00e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 084: Energy stalled at -26.036115
#  >>> Lowering LR: 5.00e-02 --> 2.50e-02
# =======================================================
#
# Iteration 090: Energy = -26.039513, Var = 0.0525, LR = 2.50e-02
# Iteration 100: Energy = -26.038003, Var = 0.0496, LR = 2.50e-02
# Iteration 110: Energy = -26.037179, Var = 0.0472, LR = 2.50e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 114: Energy stalled at -26.041306
#  >>> Lowering LR: 2.50e-02 --> 1.25e-02
# =======================================================
#
# Iteration 120: Energy = -26.036682, Var = 0.0435, LR = 1.25e-02
# Iteration 130: Energy = -26.035049, Var = 0.0426, LR = 1.25e-02
# Iteration 140: Energy = -26.035957, Var = 0.0448, LR = 1.25e-02
#
# =======================================================
#  >>> [LR REDUCTION] Step 144: Energy stalled at -26.041801
#  >>> Lowering LR: 1.25e-02 --> 6.25e-03
# =======================================================
#
# Iteration 150: Energy = -26.043036, Var = 0.0441, LR = 6.25e-03
#
# ============================================================
#  >>> [EARLY STOPPING] Step 154: No energy improvement over last 100 steps.
#  >>> Restoring best parameters from step 054 (Energy: -26.051020)...
# ============================================================
#
# Stopping early because of :  Legacy callback <function netket_pipeline.<locals>.master_callback at 0x79f88de5b920> requested to stop the run.
#
# Restored best model weights from step 054 (Energy: -26.051020)
#
# Relative error   : 0.00023836906334672597
#
# ========================================
# Mean Energy:        -26.025859
# Error Bar:          ± 0.005489
# Variance:           0.058398
# Final VMC Energy:   -26.043089
# Energy per Fermion: -1.084411
# ========================================
# Final model weights saved to: qsk_N=24/seed_qsk=9012/seed=303/hrbm_alpha=1_ML_final_params.mpack
# Time taken = 59.44946885108948 (secs)
# ===================================================================================

# %% [markdown]
# # Clear repo

# %%
import shutil
import os

# Define the path to the cloned repository folder inside Kaggle
repo_folder_path = '/kaggle/working/syk_hyprbm'

# Clean it up so it doesn't clutter notebook output files
if os.path.exists(repo_folder_path):
    shutil.rmtree(repo_folder_path)
    print(f"Successfully removed {repo_folder_path} from working directory.")
